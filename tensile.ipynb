# %%
import pandas as pd
import pathlib
import numpy as np
import matplotlib.pyplot as plt

# %%
data=[]
for name in pathlib.Path(".").glob("*.tbl"):
    data.append((name,pd.read_table(name, skiprows=4)))

# %%
plt.figure(figsize=(12, 4))
for name, tbl in data:
    plt.plot(tbl["dL(mm)"],tbl["F(Kn)"],label=name)
plt.legend()

# %%
data[0][1]['F(Kn)']*1000/(np.pi*2.5*2.5) /data[0][1]['dL(mm)']*25
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#           ...
# 101    9674.123992
# 102    9111.809064
# 103    8469.059415
# 104    8112.676745
# 105    7531.076456
# Length: 106, dtype: float64

# %%
data[0][1]['dL(mm)']/25
# Out:
# 0      0.0000
# 1      0.0000
# 2      0.0000
# 3      0.0000
# 4      0.0000
#         ...
# 101    0.0816
# 102    0.0844
# 103    0.0884
# 104    0.0904
# 105    0.0940
# Name: dL(mm), Length: 106, dtype: float64
